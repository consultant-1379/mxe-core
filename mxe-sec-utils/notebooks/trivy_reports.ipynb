# %%
import pandas as pd 
import json
import os

# %%
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', False)

# %%
input_dir = os.getenv('TRIVY_SCAN_REPORTS_DIR', default = '../../.bob/va-reports/trivy')
output_dir = os.getenv('TRIVY_ANALYSIS_REPORTS_DIR', default ='../../.bob/va-reports/analysis-reports/trivy')

# %%
from datetime import datetime
runDate= datetime.today().strftime('%Y%m%d')
runDate
# Out:
# '20220428'

# %% [markdown]
# #### Report to Name Mapping

# %%
REPORT_NAMES={  'CVE_COUNT_BY_SEVERITY' : 'cve_count_by_severity',
                'CVE_COUNT_BY_SEVERITY_AND_AGE' : 'cve_count_by_severity_and_age',
                'IMAGE_COUNT_BY_CVE': 'image_count_by_cve',
                'DETAILED_REPORT': 'detailed_report', 
                'CONSOLIDATED_EXCEL_REPORT' : f'mxe_va_analysis_report_{runDate}'
}

# %% [markdown]
# ## Get all 2PP, 3PP scan json reports by doing a recursive walk of scan output folder

# %%
json_files = [os.path.join(dp, f) 
            for dp, dn, filenames in os.walk(input_dir) 
                for f in filenames if f.endswith('.json')]
print(len(json_files))
json_files
# Out:
# 66
# ['../../.bob/va-reports/trivy/internal-reports/keycloak-init.json',
#  '../../.bob/va-reports/trivy/internal-reports/db-init.json',
#  '../../.bob/va-reports/trivy/internal-reports/pre-upgrade-job.json',
#  '../../.bob/va-reports/trivy/internal-reports/gui.json',
#  '../../.bob/va-reports/trivy/internal-reports/model-service.json',
#  '../../.bob/va-reports/trivy/internal-reports/jupyterlab.json',
#  '../../.bob/va-reports/trivy/internal-reports/eric-mxe-gatekeeper.json',
#  '../../.bob/va-reports/trivy/internal-reports/author-service.json',
#  '../../.bob/va-reports/trivy/internal-reports/mxe-deployer-init.json',
#  '../../.bob/va-reports/trivy/internal-reports/mxe-deployer-service.json',
#  '../../.bob/va-reports/trivy/internal-reports/pypi-eea.json',
#  '../../.bob/va-reports/trivy/internal-reports/model-packager.json',
#  '../../.bob/va-reports/trivy/internal-reports/default-backend.json',
#  '../../.bob/va-reports/trivy/internal-reports/kafka-pyconsumer.json',
#  '../../.bob/va-reports/trivy/internal-reports/model-python-base.json',
#  '../../.bob/va-reports/trivy/internal-reports/model-training-packager.json',
#  '../../.bob/va-reports/trivy/internal-reports/model-catalogue-service.json',
#  '../../.bob/va-reports/trivy/internal-reports/kubernetes-modifier.json',
#  '../../.bob/va-reports/trivy/internal-reports/jupyterhub.json',
#  '../../.bob/va-reports/trivy/internal-reports/model-training-service.json',
#  '../../.bob/va-reports/trivy/3pp-reports/argocd.json',
#  '../../.bob/va-reports/trivy/3pp-reports/pypiserver.json',
#  '../../.bob/va-reports/trivy/3pp-reports/argocli.json',
#  '../../.bob/va-reports/trivy/3pp-reports/spark-operator.json',
#  '../../.bob/va-reports/trivy/3pp-reports/configurable-http-proxy.json',
#  '../../.bob/va-reports/trivy/3pp-reports/ambassador.json',
#  '../../.bob/va-reports/trivy/3pp-reports/workflow-controller.json',
#  '../../.bob/va-reports/trivy/3pp-reports/k8s-image-awaiter.json',
#  '../../.bob/va-reports/trivy/3pp-reports/haproxy.json',
#  '../../.bob/va-reports/trivy/3pp-reports/controller.json',
#  '../../.bob/va-reports/trivy/3pp-reports/k8s-network-tools.json',
#  '../../.bob/va-reports/trivy/3pp-reports/argoexec.json',
#  '../../.bob/va-reports/trivy/3pp-reports/redis.json',
#  '../../.bob/va-reports/trivy/3pp-reports/mxe-gitea.json',
#  '../../.bob/va-reports/trivy/3pp-reports/seldon-core-s2i-python37.json',
#  '../../.bob/va-reports/trivy/3pp-reports/seldon-core-operator.json',
#  '../../.bob/va-reports/trivy/3pp-reports/mxe-memcached.json',
#  '../../.bob/va-reports/trivy/3pp-reports/mc.json',
#  '../../.bob/va-reports/trivy/3pp-reports/seldon-core-executor.json',
#  '../../.bob/va-reports/trivy/3pp-reports/pause.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-authnproxy.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-cr-sidecar.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-cr-bragent.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-kube-client.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-object-storage-mn-init.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-sip-oauth2.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-mesh-tools.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-image.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-pm-reverseproxy.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-pm-server.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-metrics.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-mesh-proxy.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-brm13.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-cr-registry.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-mesh-controller.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-bra.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-pg13.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-cr-migration.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-object-storage-bra.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-cr-init.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-data-object-storage-mn.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-initcontainer.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-log-shipper.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-ctrl-bro.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-pm-exporter.json',
#  '../../.bob/va-reports/trivy/2pp-reports/eric-pm-configmap-reload.json']

# %% [markdown]
# ### Load trivy report scans
#
# Considerations
#
# 1. Some files only have "null" as content.  So on reading file content as json, json_data will not contain anything, hence; only proceed loading the json_data into pd if it contains anything
#
#
# 2. Each file contains a list of dicts. And we are interested in the Vulnerabilities key inside every dict.
# pandas json_normalize can be used to flatten nested dicts present in Vulnerabilities section , however not every dict in the list has Vulnerabilities key and this is breaking the load to pandas. To circumvent this issue, preprocess the json_data and insert a key 'Vulnerabilities' if it does not exist in the dict
# Ex:
# We explicitly look for 'Vulnerabilities' key to normalize, but entries like below dont have this key. So we insert `'Vulnerabilities' :[]`
# ```
# {
#     "Target": "opt/spark/jars/commons-beanutils-1.9.4.jar",
#     "Class": "lang-pkgs",
#     "Type": "jar"
# }
# ```

# %%
def load_json(json_file):
    with open(json_file) as jsonReport:
        json_data= json.load(jsonReport)
    if json_data:
        for entry in json_data: 
            if not 'Vulnerabilities' in entry: 
                entry['Vulnerabilities']=[]
    return json_data

def load_json_normalized(json_file):
    json_data=load_json(json_file)
    if json_data:
        df=pd.json_normalize(json_data, record_path=['Vulnerabilities'], meta=['Target','Class', 'Type'])
        df.insert(loc=0, column='image_name', value=os.path.basename(json_file))
        return df
    return pd.DataFrame() 

def load_schema_version2_json(json_file):
    with open(json_file) as jsonReport:
        json_data= json.load(jsonReport)
    if json_data:
        if "Results" in json_data: 
            results = json_data['Results']
            for entry in results: 
                if not 'Vulnerabilities' in entry: 
                    entry['Vulnerabilities']=[]
                if not 'Type' in entry:
                    entry['Type']="" 
    return json_data   

def load_schema_version2_json_normalized(json_file):
    json_data=load_schema_version2_json(json_file)
    print(json_file)
    if json_data and 'Results' in json_data:
        artifactName=json_data['ArtifactName']
        artifactType=json_data['ArtifactType']
        metadata=json_data['Metadata']
        metadataOSFamily='Unknown'
        metadataOSName='Unknown'
        repoTags='Unknown'
        repoDigests='Unknown'
        if 'OS' in  metadata: 
            metadataOSFamily=metadata['OS']['Family']
            metadataOSName=metadata['OS']['Name']
        if 'RepoTags' in metadata:
            repoTags=metadata['RepoTags'][0]
        if 'RepoDigests' in metadata:
            repoDigests=metadata['RepoDigests'][0]
        df=pd.json_normalize(json_data['Results'], record_path=['Vulnerabilities'], meta=['Target', 'Class', 'Type'])
        df.insert(loc=0, column='image_name', value=os.path.basename(json_file))
        df.insert(loc=0, column='artifactName', value=os.path.basename(artifactName))
        df.insert(loc=0, column='artifactType', value=os.path.basename(artifactType))
        df.insert(loc=0, column='metadataOSFamily', value=os.path.basename(metadataOSFamily))
        df.insert(loc=0, column='metadataOSName', value=os.path.basename(metadataOSName))
        df.insert(loc=0, column='repoTags', value=os.path.basename(repoTags))
        df.insert(loc=0, column='repoDigests', value=os.path.basename(repoDigests))
        return df
    return pd.DataFrame() 

dfs=[load_schema_version2_json_normalized(json_file) for json_file in json_files]
df=pd.concat(dfs)
# Out:
# ../../.bob/va-reports/trivy/internal-reports/keycloak-init.json
# ../../.bob/va-reports/trivy/internal-reports/db-init.json
# ../../.bob/va-reports/trivy/internal-reports/pre-upgrade-job.json
# ../../.bob/va-reports/trivy/internal-reports/gui.json
# ../../.bob/va-reports/trivy/internal-reports/model-service.json
# ../../.bob/va-reports/trivy/internal-reports/jupyterlab.json
# ../../.bob/va-reports/trivy/internal-reports/eric-mxe-gatekeeper.json
# ../../.bob/va-reports/trivy/internal-reports/author-service.json
# ../../.bob/va-reports/trivy/internal-reports/mxe-deployer-init.json
# ../../.bob/va-reports/trivy/internal-reports/mxe-deployer-service.json
# ../../.bob/va-reports/trivy/internal-reports/pypi-eea.json
# ../../.bob/va-reports/trivy/internal-reports/model-packager.json
# ../../.bob/va-reports/trivy/internal-reports/default-backend.json
# ../../.bob/va-reports/trivy/internal-reports/kafka-pyconsumer.json
# ../../.bob/va-reports/trivy/internal-reports/model-python-base.json
# ../../.bob/va-reports/trivy/internal-reports/model-training-packager.json
# ../../.bob/va-reports/trivy/internal-reports/model-catalogue-service.json
# ../../.bob/va-reports/trivy/internal-reports/kubernetes-modifier.json
# {'Target': 'home/jovyan/.local/lib/python3.8/site-packages/cryptography/hazmat/primitives/serialization/ssh.py', 'Class': 'secret', 'Secrets': [{'RuleID': 'private-key', 'Category': 'AsymmetricPrivateKey', 'Severity': 'HIGH', 'Title': 'Asymmetric Private Key', 'StartLine': 52, 'EndLine': 52, 'Match': '_SK_START = b"-----BEGIN OPENSSH PRIVATE KEY-----"'}], 'Vulnerabilities': []}
# ../../.bob/va-reports/trivy/internal-reports/jupyterhub.json
# ../../.bob/va-reports/trivy/internal-reports/model-training-service.json
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/iam/2010-05-08/examples-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 130, 'EndLine': 130, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 198, 'EndLine': 198, 'Match': '"InstanceProfileId": "*****E",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 280, 'EndLine': 280, 'Match': '"RoleId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 305, 'EndLine': 305, 'Match': '"UserId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 676, 'EndLine': 676, 'Match': '"UserId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 699, 'EndLine': 699, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 705, 'EndLine': 705, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 774, 'EndLine': 774, 'Match': '"GroupId": "*****E",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 1017, 'EndLine': 1017, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 132, 'EndLine': 132, 'Match': '"SecretAccessKey": *****Y",'}, {'RuleID': 'private-key', 'Category': 'AsymmetricPrivateKey', 'Severity': 'HIGH', 'Title': 'Asymmetric Private Key', 'StartLine': 1140, 'EndLine': 1140, 'Match': '"PrivateKey": "-----BEGIN DSA PRIVATE KEY-----*****----END DSA PRIVATE KEY-----",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/lambda/2015-03-31/examples-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 34, 'EndLine': 34, 'Match': '"SourceAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/organizations/2016-11-28/examples-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 200, 'EndLine': 200, 'Match': '"MasterAccountId": "*****"'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 227, 'EndLine': 227, 'Match': '"MasterAccountId": "*****"'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 390, 'EndLine': 390, 'Match': '"AccountId": "*****"'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 418, 'EndLine': 418, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 890, 'EndLine': 890, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 1294, 'EndLine': 1294, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 1312, 'EndLine': 1312, 'Match': '"AccountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/rds/2014-10-31/service-2.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 13337, 'EndLine': 13337, 'Match': '"documentation":"<p>The Amazon Web Services KMS key identifier for encryption of the replicated automated backups. The KMS key ID is the Amazon Resource Name (ARN) for the KMS encryption key in the destination Amazon Web Services Region, for example, <code>arn:aws:kms:us-east-1:123456789012:key/*****</code>.</p>"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/sts/2011-06-15/examples-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 49, 'EndLine': 49, 'Match': '"AssumedRoleId": "*****E:app1"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 53, 'EndLine': 53, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 79, 'EndLine': 79, 'Match': '"DecodedMessage": "{\\"allowed\\": \\"false\\",\\"explicitDeny\\": \\"false\\",\\"matchedStatements\\": \\"\\",\\"failures\\": \\"\\",\\"context\\": {\\"principal\\": {\\"id\\": \\"*****E\\",\\"name\\": \\"Bob\\",\\"arn\\": \\"arn:aws:iam::123456789012:user/Bob\\"},\\"action\\": \\"ec2:StopInstances\\",\\"resource\\": \\"arn:aws:ec2:us-east-1:123456789012:instance/i-dd01c9bd\\",\\"conditions\\": [{\\"item\\": {\\"key\\": \\"ec2:Tenancy\\",\\"values\\": [\\"default\\"]},{\\"item\\": {\\"key\\": \\"ec2:ResourceTag/elasticbeanstalk:environment-name\\",\\"values\\": [\\"Default-Environment\\"]}},(Additional items ...)]}}"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 99, 'EndLine': 99, 'Match': '"UserId": "*****"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 117, 'EndLine': 117, 'Match': '"UserId": "*****:my-role-session-name"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 157, 'EndLine': 157, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 188, 'EndLine': 188, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 97, 'EndLine': 97, 'Match': '"Account": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 115, 'EndLine': 115, 'Match': '"Account": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 133, 'EndLine': 133, 'Match': '"Account": "*****",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 21, 'EndLine': 21, 'Match': '"SecretAccessKey": *****Y",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 55, 'EndLine': 55, 'Match': '"SecretAccessKey": *****Y",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 159, 'EndLine': 159, 'Match': '"SecretAccessKey": *****Y",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 190, 'EndLine': 190, 'Match': '"SecretAccessKey": *****Y",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/sts/2011-06-15/service-2.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 105, 'EndLine': 105, 'Match': '"documentation":"<p>Returns the account identifier for the specified access key ID.</p> <p>Access keys consist of two parts: an access key ID (for example, <code>*****</code>) and a secret access key (for example, <code>wJalrXUtnFEMI/K7MDENG/bPxRfiCYEXAMPLEKEY</code>). For more information about access keys, see <a href=\\"https://docs.aws.amazon.com/IAM/latest/UserGuide/id_credentials_access-keys.html\\">Managing Access Keys for IAM Users</a> in the <i>IAM User Guide</i>.</p> <p>When you pass an access key ID to this operation, it returns the ID of the Amazon Web Services account to which the keys belong. Access key IDs beginning with <code>AKIA</code> are long-term credentials for an IAM user or the Amazon Web Services account root user. Access key IDs beginning with <code>ASIA</code> are temporary credentials that are created using STS operations. If the account in the response belongs to you, you can sign in as the root user and review your root user access keys. Then, you can pull a <a href=\\"https://docs.aws.amazon.com/IAM/latest/UserGuide/id_credentials_getting-report.html\\">credentials report</a> to learn which IAM user owns the keys. To learn who requested the temporary credentials for an <code>ASIA</code> access key, view the STS events in your <a href=\\"https://docs.aws.amazon.com/IAM/latest/UserGuide/cloudtrail-integration.html\\">CloudTrail logs</a> in the <i>IAM User Guide</i>.</p> <p>This operation does not indicate the state of the access key. The key might be active, inactive, or deleted. Active keys might not have permissions to perform an operation. Providing a deleted access key might return an error that the key doesn\'t exist.</p>"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/comprehend/2017-11-27/paginators-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 25, 'EndLine': 25, 'Match': '"result_key": *****st"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/config/2014-11-12/paginators-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 159, 'EndLine': 159, 'Match': '"result_key": *****ses"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/ec2/2016-11-15/paginators-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 465, 'EndLine': 465, 'Match': '"result_key": *****oupAssociations"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/ec2/2016-11-15/examples-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 172, 'EndLine': 172, 'Match': '"Id": "*****C"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 1933, 'EndLine': 1933, 'Match': '"Id": "*****M"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 3751, 'EndLine': 3751, 'Match': '"Id": "*****Y"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/kms/2014-11-01/examples-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 84, 'EndLine': 84, 'Match': '"AWSAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 169, 'EndLine': 169, 'Match': '"AWSAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/service-quotas/2019-06-24/paginators-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 25, 'EndLine': 25, 'Match': '"result_key": *****t"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/botocore/data/cloud9/2017-09-23/examples-1.json', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 40, 'EndLine': 40, 'Match': '"userId": "*****X"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 102, 'EndLine': 102, 'Match': '"userId": "*****X"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 108, 'EndLine': 108, 'Match': '"userId": "*****X"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 135, 'EndLine': 135, 'Match': '"userId": "*****X"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 160, 'EndLine': 160, 'Match': '"userId": "*****X"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 167, 'EndLine': 167, 'Match': '"userId": "*****X"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 293, 'EndLine': 293, 'Match': '"userId": "*****X"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/outposts/list-sites.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 13, 'EndLine': 13, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ram/accept-resource-share-invitation.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"senderAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 16, 'EndLine': 16, 'Match': '"receiverAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ram/create-resource-share.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"owningAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 45, 'EndLine': 45, 'Match': '"owningAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ram/get-resource-share-invitations.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"senderAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 16, 'EndLine': 16, 'Match': '"receiverAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ram/get-resource-shares.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"owningAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 30, 'EndLine': 30, 'Match': '"owningAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ram/reject-resource-share-invitation.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"senderAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 16, 'EndLine': 16, 'Match': '"receiverAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ram/update-resource-share.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"owningAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/sts/assume-role-with-saml.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 20, 'EndLine': 20, 'Match': '"SecretAccessKey": *****Y",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/sts/assume-role-with-web-identity.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 20, 'EndLine': 20, 'Match': '"AssumedRoleId": "*****E:app1"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 24, 'EndLine': 24, 'Match': '"SecretAccessKey": *****Y",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/sts/assume-role.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 9, 'EndLine': 9, 'Match': '"AssumedRoleId": "*****4:s3-access-example",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 16, 'EndLine': 16, 'Match': '"AccessKeyId": "*****A"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/sts/get-caller-identity.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 11, 'EndLine': 11, 'Match': '"Account": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/sts/get-session-token.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"AccessKeyId": "*****",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 15, 'EndLine': 15, 'Match': '"SecretAccessKey": *****Y",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codecommit/batch-get-repositories.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"accountId": "*****"'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 35, 'EndLine': 35, 'Match': '"accountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codecommit/create-repository.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 20, 'EndLine': 20, 'Match': '"accountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codecommit/get-repository.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 21, 'EndLine': 21, 'Match': '"accountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codepipeline/get-job-details.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 31, 'EndLine': 31, 'Match': '"accessKeyId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"accountId": "*****",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 32, 'EndLine': 32, 'Match': '"secretAccessKey": *****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codepipeline/poll-for-jobs.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 46, 'EndLine': 46, 'Match': '"accessKeyId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 29, 'EndLine': 29, 'Match': '"accountId": "*****",'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 47, 'EndLine': 47, 'Match': '"secretAccessKey": *****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/devicefarm/create-upload.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 16, 'EndLine': 16, 'Match': '"url": "https://prod-us-west-2-uploads.s3-us-west-2.amazonaws.com/arn%3Aaws%3Adevicefarm%3Aus-west-2%3A123456789012%3Aproject%3A070fc3ca-c7e1-4471-91cf-d3e4efc50604/uploads/arn%3Aaws%3Adevicefarm%3Aus-west-2%3A123456789012%3Aupload%3A070fc3ca-7ec1-4741-9c1f-d3e044efc506/dd72723a-ae9e-4087-09e6-f4cea3599514/app.apk?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20170824T224008Z&X-Amz-SignedHeaders=host&X-Amz-Expires=86400&X-Amz-Credential=*****%2F20170824%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=05050370c38894ef5bd09f5d009f36fc8f96fa4bb04e1bba9aca71b8dbe49a0f",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 24, 'EndLine': 24, 'Match': 'curl -T app.apk "https://prod-us-west-2-uploads.s3-us-west-2.amazonaws.com/arn%3Aaws%3Adevicefarm%3Aus-west-2%3A123456789012%3Aproject%3A070fc3ca-c7e1-4471-91cf-d3e4efc50604/uploads/arn%3Aaws%3Adevicefarm%3Aus-west-2%3A123456789012%3Aupload%3A070fc3ca-7ec1-4741-9c1f-d3e044efc506/dd72723a-ae9e-4087-09e6-f4cea3599514/app.apk?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20170824T224008Z&X-Amz-SignedHeaders=host&X-Amz-Expires=86400&X-Amz-Credential=*****%2F20170824%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=05050370c38894ef5bd09f5d009f36fc8f96fa4bb04e1bba9aca71b8dbe49a0f"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/iotwireless/update-partner-account.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 8, 'EndLine': 8, 'Match': '--sidewalk AppServerPrivateKey=*****989425b7c6d2146dd6c815bb"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/iotwireless/associate-aws-account-with-partner-account.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 6, 'EndLine': 6, 'Match': '--sidewalk AmazonId="12345678901234",AppServerPrivateKey=*****6f78a1b234c56d7e890a1234"'}, {'RuleID': 'aws-secret-access-key', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Secret Access Key', 'StartLine': 13, 'EndLine': 13, 'Match': '"AppServerPrivateKey": *****6f78a1b234c56d7e890a1234"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/organizations/create-organization.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 17, 'EndLine': 17, 'Match': '"MasterAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 41, 'EndLine': 41, 'Match': '"MasterAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/organizations/describe-create-account-status.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/organizations/describe-organization.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 13, 'EndLine': 13, 'Match': '"MasterAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/organizations/list-create-account-status.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/redshift/modify-cluster-snapshot.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 29, 'EndLine': 29, 'Match': '"OwnerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/redshift/revoke-snapshot-access.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"OwnerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/redshift/authorize-snapshot-access.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 22, 'EndLine': 22, 'Match': '"OwnerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/redshift/describe-cluster-snapshots.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"OwnerAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 40, 'EndLine': 40, 'Match': '"OwnerAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 49, 'EndLine': 49, 'Match': '"AccountID": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ssm/get-deployable-patch-snapshot-for-instance.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 17, 'EndLine': 17, 'Match': '"SnapshotDownloadUrl": "https://patch-baseline-snapshot-us-east-1.s3.amazonaws.com/ed85194ef27214f5984f28b4d664d14f7313568fea7d4b6ac6c10ad1f729d7e7-773304212436/AMAZON_LINUX-521c3536-930c-4aa9-950e-01234567abcd?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20190215T164031Z&X-Amz-SignedHeaders=host&X-Amz-Expires=86400&X-Amz-Credential=*****%2F20190215%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=efaaaf6e3878e77f48a6697e015efdbda9c426b09c5822055075c062f6ad2149"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ssm/get-ops-summary.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 18, 'EndLine': 18, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 45, 'EndLine': 45, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/list-repositories.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 13, 'EndLine': 13, 'Match': '"administratorAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 21, 'EndLine': 21, 'Match': '"administratorAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 29, 'EndLine': 29, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/update-repository.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/associate-external-connection.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/create-repository.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 16, 'EndLine': 16, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/delete-repository.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/describe-repository.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/disassociate-external-connection.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/codeartifact/list-repositories-in-domain.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"administratorAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 22, 'EndLine': 22, 'Match': '"administratorAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/comprehendmedical/describe-icd10-cm-inference-job.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"S3Key": "*****"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"S3Key": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/comprehendmedical/describe-rx-norm-inference-job.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"S3Key": "*****"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"S3Key": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/comprehendmedical/list-icd10-cm-inference-jobs.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"S3Key": "*****"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"S3Key": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/comprehendmedical/list-rx-norm-inference-jobs.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"S3Key": "*****"'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"S3Key": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/detective/list-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 13, 'EndLine': 13, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 23, 'EndLine': 23, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/detective/create-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 6, 'EndLine': 6, 'Match': '--accounts AccountId=*****,EmailAddress=mmajor@example.com AccountId=123456789012,EmailAddress=jstiles@example.com \\'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 6, 'EndLine': 6, 'Match': '--accounts AccountId=444455556666,EmailAddress=mmajor@example.com AccountId=*****,EmailAddress=jstiles@example.com \\'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 25, 'EndLine': 25, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 45, 'EndLine': 45, 'Match': '--accounts AccountId=*****,EmailAddress=mmajor@example.com AccountId=123456789012,EmailAddress=jstiles@example.com \\'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 45, 'EndLine': 45, 'Match': '--accounts AccountId=444455556666,EmailAddress=mmajor@example.com AccountId=*****,EmailAddress=jstiles@example.com \\'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 54, 'EndLine': 54, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 64, 'EndLine': 64, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/detective/get-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 24, 'EndLine': 24, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/detective/list-invitations.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/greengrass/create-device-definition.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'private-key', 'Category': 'AsymmetricPrivateKey', 'Severity': 'HIGH', 'Title': 'Asymmetric Private Key', 'StartLine': 34, 'EndLine': 34, 'Match': '"PrivateKey": "-----BEGIN RSA PRIVATE KEY-----*****----END RSA PRIVATE KEY-----\\n"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/greengrass/create-core-definition-version.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'private-key', 'Category': 'AsymmetricPrivateKey', 'Severity': 'HIGH', 'Title': 'Asymmetric Private Key', 'StartLine': 33, 'EndLine': 33, 'Match': '"PrivateKey": "-----BEGIN RSA PRIVATE KEY-----*****----END RSA PRIVATE KEY-----\\n"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/greengrass/create-core-definition.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'private-key', 'Category': 'AsymmetricPrivateKey', 'Severity': 'HIGH', 'Title': 'Asymmetric Private Key', 'StartLine': 50, 'EndLine': 50, 'Match': '"PrivateKey": "-----BEGIN RSA PRIVATE KEY-----*****----END RSA PRIVATE KEY-----\\n"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/greengrass/create-device-definition-version.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'private-key', 'Category': 'AsymmetricPrivateKey', 'Severity': 'HIGH', 'Title': 'Asymmetric Private Key', 'StartLine': 34, 'EndLine': 34, 'Match': '"PrivateKey": "-----BEGIN RSA PRIVATE KEY-----*****----END RSA PRIVATE KEY-----\\n"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/cloudtrail/lookup-events.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"CloudTrailEvent": "{\\"eventVersion\\":\\"1.02\\",\\"userIdentity\\":{\\"type\\":\\"AssumedRole\\",\\"principalId\\":\\"*****4:my-session-name\\",\\"arn\\":\\"arn:aws:sts::123456789012:assumed-role/my-role/my-session-name\\",\\"accountId\\":\\"123456789012\\",\\"sessionContext\\":{\\"attributes\\":{\\"mfaAuthenticated\\":\\"false\\",\\"creationDate\\":\\"2016-01-26T21:42:12Z\\"},\\"sessionIssuer\\":{\\"type\\":\\"Role\\",\\"principalId\\":\\"*****4\\",\\"arn\\":\\"arn:aws:iam::123456789012:role/my-role\\",\\"accountId\\":\\"123456789012\\",\\"userName\\":\\"my-role\\"}}},\\"eventTime\\":\\"2016-01-26T21:42:12Z\\",\\"eventSource\\":\\"signin.amazonaws.com\\",\\"eventName\\":\\"ConsoleLogin\\",\\"awsRegion\\":\\"us-east-1\\",\\"sourceIPAddress\\":\\"72.21.198.70\\",\\"userAgent\\":\\"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36\\",\\"requestParameters\\":null,\\"responseElements\\":{\\"ConsoleLogin\\":\\"Success\\"},\\"additionalEventData\\":{\\"MobileVersion\\":\\"No\\",\\"MFAUsed\\":\\"No\\"},\\"eventID\\":\\"654ccbc0-ba0d-486a-9076-dbf7274677a7\\",\\"eventType\\":\\"AwsConsoleSignIn\\",\\"recipientAccountId\\":\\"123456789012\\"}",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"CloudTrailEvent": "{\\"eventVersion\\":\\"1.02\\",\\"userIdentity\\":{\\"type\\":\\"AssumedRole\\",\\"principalId\\":\\"*****4:my-session-name\\",\\"arn\\":\\"arn:aws:sts::123456789012:assumed-role/my-role/my-session-name\\",\\"accountId\\":\\"123456789012\\",\\"sessionContext\\":{\\"attributes\\":{\\"mfaAuthenticated\\":\\"false\\",\\"creationDate\\":\\"2016-01-26T21:42:12Z\\"},\\"sessionIssuer\\":{\\"type\\":\\"Role\\",\\"principalId\\":\\"*****4\\",\\"arn\\":\\"arn:aws:iam::123456789012:role/my-role\\",\\"accountId\\":\\"123456789012\\",\\"userName\\":\\"my-role\\"}}},\\"eventTime\\":\\"2016-01-26T21:42:12Z\\",\\"eventSource\\":\\"signin.amazonaws.com\\",\\"eventName\\":\\"ConsoleLogin\\",\\"awsRegion\\":\\"us-east-1\\",\\"sourceIPAddress\\":\\"72.21.198.70\\",\\"userAgent\\":\\"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36\\",\\"requestParameters\\":null,\\"responseElements\\":{\\"ConsoleLogin\\":\\"Success\\"},\\"additionalEventData\\":{\\"MobileVersion\\":\\"No\\",\\"MFAUsed\\":\\"No\\"},\\"eventID\\":\\"654ccbc0-ba0d-486a-9076-dbf7274677a7\\",\\"eventType\\":\\"AwsConsoleSignIn\\",\\"recipientAccountId\\":\\"123456789012\\"}",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/cognito-idp/describe-user-pool-domain.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"AWSAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/associate-hosted-connection.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/create-private-virtual-interface.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/delete-connection.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 10, 'EndLine': 10, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/describe-direct-connect-gateway-association-proposals.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"directConnectGatewayOwnerAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"ownerAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 39, 'EndLine': 39, 'Match': '"directConnectGatewayOwnerAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 44, 'EndLine': 44, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/disassociate-connection-from-lag.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/update-lag.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"ownerAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"ownerAccount": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 29, 'EndLine': 29, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/create-public-virtual-interface.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/update-virtual-interface-attributes.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"ownerAccount": "*****3",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/allocate-hosted-connection.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 17, 'EndLine': 17, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/allocate-transit-virtual-interface.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/directconnect/associate-connection-with-lag.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"ownerAccount": "*****",'}], 'Vulnerabilities': []}
# ...
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/rds/describe-db-cluster-snapshots.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 33, 'EndLine': 33, 'Match': '"KmsKeyId": "arn:aws:kms:us-east-1:123456789012:key/*****",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 58, 'EndLine': 58, 'Match': '"KmsKeyId": "arn:aws:kms:us-east-1:814387698303:key/*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/get-insight-results.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 17, 'EndLine': 17, 'Match': '"GroupByAttributeValue": "AWS::::Account:*****"'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 21, 'EndLine': 21, 'Match': '"GroupByAttributeValue": "AWS::::Account:*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/get-master-account.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 11, 'EndLine': 11, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/list-invitations.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/list-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 20, 'EndLine': 20, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/batch-import-findings.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 8, 'EndLine': 8, 'Match': '"AwsAccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/get-administrator-account.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 11, 'EndLine': 11, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/get-findings.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 18, 'EndLine': 18, 'Match': '"AwsAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 64, 'EndLine': 64, 'Match': '"Id": "AWS::::Account:*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 106, 'EndLine': 106, 'Match': '"AwsAccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 152, 'EndLine': 152, 'Match': '"Id": "AWS::::Account:*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/get-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 13, 'EndLine': 13, 'Match': '"AccountId": "*****",'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 21, 'EndLine': 21, 'Match': '"AccountId": "*****",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/list-organization-admin-accounts.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 11, 'EndLine': 11, 'Match': '{ "AccountId": "*****" },'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/securityhub/create-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 6, 'EndLine': 6, 'Match': '--account-details \'[{"AccountId": "*****"}, {"AccountId": "123456789222"}]\''}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 6, 'EndLine': 6, 'Match': '--account-details \'[{"AccountId": "123456789111"}, {"AccountId": "*****"}]\''}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/guardduty/create-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 7, 'EndLine': 7, 'Match': '--account-details AccountId=*****,Email=first+member@example.com AccountId=111111111111 ,Email=another+member@example.com'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 7, 'EndLine': 7, 'Match': '--account-details AccountId=111122223333,Email=first+member@example.com AccountId=***** ,Email=another+member@example.com'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/guardduty/get-findings.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"PrincipalId": "*****E",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 20, 'EndLine': 20, 'Match': '"AccessKeyId": "*****"'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 70, 'EndLine': 70, 'Match': '"AccountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/guardduty/get-master-account.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"AccountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/guardduty/list-invitations.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"AccountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/guardduty/list-members.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 19, 'EndLine': 19, 'Match': '"AccountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/s3api/get-bucket-inventory-configuration.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 18, 'EndLine': 18, 'Match': '"AccountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/s3api/list-bucket-inventory-configurations.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 18, 'EndLine': 18, 'Match': '"AccountId": "*****"'}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 33, 'EndLine': 33, 'Match': '"AccountId": "*****"'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/s3api/put-bucket-inventory-configuration.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 8, 'EndLine': 8, 'Match': '--inventory-configuration \'{"Destination": { "S3BucketDestination": { "AccountId": "*****", "Bucket": "arn:aws:s3:::my-bucket", "Format": "ORC" }}, "IsEnabled": true, "Id": "1", "IncludedObjectVersions": "Current", "Schedule": { "Frequency": "Weekly" }}\''}, {'RuleID': 'aws-account-id', 'Category': 'AWS', 'Severity': 'HIGH', 'Title': 'AWS Account ID', 'StartLine': 19, 'EndLine': 19, 'Match': '--inventory-configuration \'{"Destination": { "S3BucketDestination": { "AccountId": "*****", "Bucket": "arn:aws:s3:::my-bucket", "Format": "CSV" }}, "IsEnabled": true, "Id": "2", "IncludedObjectVersions": "Current", "Schedule": { "Frequency": "Daily" }}\''}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/cloud9/create-environment-membership.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"userId": "*****X",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/cloud9/describe-environment-memberships.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 15, 'EndLine': 15, 'Match': '"userId": "*****X",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 21, 'EndLine': 21, 'Match': '"userId": "*****X",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 42, 'EndLine': 42, 'Match': '"userId": "*****X",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 64, 'EndLine': 64, 'Match': '"userId": "*****X",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 71, 'EndLine': 71, 'Match': '"userId": "*****X",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/cloud9/update-environment-membership.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 14, 'EndLine': 14, 'Match': '"userId": "*****X",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/dlm/create-default-role.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 37, 'EndLine': 37, 'Match': '"RoleId": "*****PLE",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/ecr/get-download-url-for-layer.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 12, 'EndLine': 12, 'Match': '"downloadUrl": "https://prod-us-west-2-starport-layer-bucket.s3.us-west-2.amazonaws.com/e501-012345678910-9cb60dc0-7284-5643-3987-da6dac0465f0/04620aac-66a5-4167-8232-55ee7ef6d565?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20190814T220617Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=*****%2F20190814%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=9161345894947a1672467a0da7a1550f2f7157318312fe4941b59976239c3337",'}], 'Vulnerabilities': []}
# {'Target': 'usr/local/aws-cli/v2/current/dist/awscli/examples/emr/create-default-roles.rst', 'Class': 'secret', 'Secrets': [{'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 62, 'EndLine': 62, 'Match': '"RoleId": "*****6",'}, {'RuleID': 'aws-access-key-id', 'Category': 'AWS', 'Severity': 'CRITICAL', 'Title': 'AWS Access Key ID', 'StartLine': 134, 'EndLine': 134, 'Match': '"RoleId": "*****Y",'}], 'Vulnerabilities': []}
# ../../.bob/va-reports/trivy/3pp-reports/argocd.json
# ../../.bob/va-reports/trivy/3pp-reports/pypiserver.json
# ../../.bob/va-reports/trivy/3pp-reports/argocli.json
# ../../.bob/va-reports/trivy/3pp-reports/spark-operator.json
# ../../.bob/va-reports/trivy/3pp-reports/configurable-http-proxy.json
# ../../.bob/va-reports/trivy/3pp-reports/ambassador.json
# ../../.bob/va-reports/trivy/3pp-reports/workflow-controller.json
# ../../.bob/va-reports/trivy/3pp-reports/k8s-image-awaiter.json
# ../../.bob/va-reports/trivy/3pp-reports/haproxy.json
# ../../.bob/va-reports/trivy/3pp-reports/controller.json
# ../../.bob/va-reports/trivy/3pp-reports/k8s-network-tools.json
# ../../.bob/va-reports/trivy/3pp-reports/argoexec.json
# ../../.bob/va-reports/trivy/3pp-reports/redis.json
# ../../.bob/va-reports/trivy/3pp-reports/mxe-gitea.json
# {'Target': 'home/mxe/python3.7/site-packages/cryptography/hazmat/primitives/serialization/ssh.py', 'Class': 'secret', 'Secrets': [{'RuleID': 'private-key', 'Category': 'AsymmetricPrivateKey', 'Severity': 'HIGH', 'Title': 'Asymmetric Private Key', 'StartLine': 52, 'EndLine': 52, 'Match': '_SK_START = b"-----BEGIN OPENSSH PRIVATE KEY-----"'}], 'Vulnerabilities': []}
# ../../.bob/va-reports/trivy/3pp-reports/seldon-core-s2i-python37.json
# ../../.bob/va-reports/trivy/3pp-reports/seldon-core-operator.json
# ../../.bob/va-reports/trivy/3pp-reports/mxe-memcached.json
# ../../.bob/va-reports/trivy/3pp-reports/mc.json
# ../../.bob/va-reports/trivy/3pp-reports/seldon-core-executor.json
# ../../.bob/va-reports/trivy/3pp-reports/pause.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-authnproxy.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-cr-sidecar.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-cr-bragent.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-kube-client.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-object-storage-mn-init.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-sip-oauth2.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-mesh-tools.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-image.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-pm-reverseproxy.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-pm-server.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-metrics.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-mesh-proxy.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-brm13.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-cr-registry.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-mesh-controller.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-bra.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-document-database-pg13.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-cr-migration.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-object-storage-bra.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-cr-init.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-data-object-storage-mn.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-sec-access-mgmt-initcontainer.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-log-shipper.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-ctrl-bro.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-pm-exporter.json
# ../../.bob/va-reports/trivy/2pp-reports/eric-pm-configmap-reload.json

# %% [markdown]
# ## Distinct Vuln Sources
#
# AFAIK only NVD data (VulnerabilityIDs beginning with CVE) would have the Published/LastModified dates. Should we just ignore the rest?

# %%
vulnDF =df[['VulnerabilityID']].drop_duplicates()

vulnDF['source']=vulnDF.apply(lambda x: x['VulnerabilityID'].split("-")[0], axis=1)

vulnDF['source'].value_counts()
# Out:
# CVE     292
# GMS      11
# SUSE     10
# GHSA      1
# Name: source, dtype: int64

# %% [markdown]
# ## Counts by Severity
#
# Reused code written for Anchore Scan, just edited the column names to match trivy dataframe column names

# %%
from collections import defaultdict
SEVERITY_DICT = defaultdict(lambda: 7)
SEVERITY_DICT.update({"CRITICAL":1, "HIGH":2, "MEDIUM":3, "LOW":4, "NEGLIGIBLE":5,"UNKNOWN":6})

# %%
unique_cves = df[['Severity', 'VulnerabilityID']].drop_duplicates()
severity_counts_df = pd.DataFrame(unique_cves['Severity'].value_counts())
severity_counts_df=severity_counts_df.reset_index()
severity_counts_df.columns = ['Severity', 'CVE_Count']
severity_counts_df['Rank'] = severity_counts_df['Severity'].map(SEVERITY_DICT)
severity_counts_df.sort_values(by=['Rank','Severity', 'CVE_Count'],inplace=True)
severity_counts_df = severity_counts_df.drop(labels=['Rank'],axis=1).reset_index(drop=True)
severity_counts_df
# Out:
#    Severity  CVE_Count
# 0  CRITICAL          6
# 1      HIGH         50
# 2    MEDIUM        154
# 3       LOW         98
# 4   UNKNOWN         12

# %%
severity_counts_df.to_html(f"{output_dir}/{REPORT_NAMES['CVE_COUNT_BY_SEVERITY']}.html")
severity_counts_df.to_csv(f"{output_dir}/{REPORT_NAMES['CVE_COUNT_BY_SEVERITY']}.csv", index=False)

# %%
detailed_report_df = df[['repoTags', 'Type', 'Class', 'VulnerabilityID', 'Severity', 'PublishedDate', 'LastModifiedDate','Description']].drop_duplicates()
detailed_report_df['Rank'] = detailed_report_df['Severity'].map(SEVERITY_DICT)
detailed_report_df.rename(columns={'repoTags': 'ImageName'}, inplace=True)

detailed_report_df.sort_values(by=['Rank', 'ImageName'], ascending=[True, True],inplace=True)
detailed_report_df = detailed_report_df.drop(labels=['Rank'],axis=1).reset_index(drop=True)
detailed_report_df.head()
# Out:
#                               ImageName      Type      Class VulnerabilityID  Severity         PublishedDate      LastModifiedDate                                        Description
# 0           author-service:2.3.0-dev-51       jar  lang-pkgs   CVE-2022-0839  CRITICAL  2022-03-04T15:15:00Z  2022-03-16T14:06:00Z  Improper Restriction of XML External Entity Re...
# 1                eric-ctrl-bro:5.4.0-35       jar  lang-pkgs  CVE-2022-22965  CRITICAL  2022-04-01T23:15:00Z  2022-04-21T14:40:00Z  A Spring MVC or Spring WebFlux application run...
# 2               eric-pm-server:9.0.0-27  gobinary  lang-pkgs  CVE-2021-43816  CRITICAL  2022-01-05T19:15:00Z  2022-04-01T14:50:00Z  containerd is an open source container runtime...
# 3  eric-sec-access-mgmt-image:11.0.0-73       jar  lang-pkgs   CVE-2022-0839  CRITICAL  2022-03-04T15:15:00Z  2022-03-16T14:06:00Z  Improper Restriction of XML External Entity Re...
# 4  eric-sec-access-mgmt-image:11.0.0-73       jar  lang-pkgs  CVE-2022-21724  CRITICAL  2022-02-02T12:15:00Z  2022-04-14T18:15:00Z  pgjdbc is the offical PostgreSQL JDBC Driver. ...

# %%
detailed_report_df.to_html(f"{output_dir}/{REPORT_NAMES['DETAILED_REPORT']}.html")
detailed_report_df.to_csv(f"{output_dir}/{REPORT_NAMES['DETAILED_REPORT']}.csv", index=False)

# %%
modified_base_df = df[df['Severity'].isin(['CRITICAL', 'HIGH'])]
modified_base_df.head(5)
# Out:
#                                          repoDigests                    repoTags metadataOSName              metadataOSFamily     artifactType                artifactName          image_name      VulnerabilityID      PkgName InstalledVersion          FixedVersion SeveritySource                            Title                                        Description Severity                                         References                                       Layer.DiffID DataSource.ID DataSource.Name                                    DataSource.URL PkgPath PrimaryURL CweIDs PublishedDate LastModifiedDate CVSS.nvd.V2Vector CVSS.nvd.V3Vector  CVSS.nvd.V2Score  CVSS.nvd.V3Score CVSS.redhat.V3Vector  CVSS.redhat.V3Score                                             Target    Class                          Type CVSS.redhat.V2Vector  CVSS.redhat.V2Score
# 0  keycloak-init@sha256:a616d074b14f04fd4a9aebd8b...  keycloak-init:2.3.0-dev-51           15.3  suse linux enterprise server  container_image  keycloak-init:2.3.0-dev-51  keycloak-init.json  SUSE-SU-2022:0844-1    libexpat1     2.2.5-3.15.1          2.2.5-3.19.1      suse-cvrf        Security update for expat  This update for expat fixes the following issu...     HIGH  [https://bugzilla.suse.com/1196025, https://bu...  sha256:a5712801d34708e0dde3b47ff22db82bd2701dc...     suse-cvrf       SUSE CVRF  https://ftp.suse.com/pub/projects/security/cvrf/     NaN        NaN    NaN           NaN              NaN               NaN               NaN               NaN               NaN                  NaN                  NaN  armdocker.rnd.ericsson.se/proj-mxe-ci-internal...  os-pkgs  suse linux enterprise server                  NaN                  NaN
# 1  keycloak-init@sha256:a616d074b14f04fd4a9aebd8b...  keycloak-init:2.3.0-dev-51           15.3  suse linux enterprise server  container_image  keycloak-init:2.3.0-dev-51  keycloak-init.json  SUSE-SU-2022:1149-1   libfreebl3    3.68.2-3.64.2  3.68.3-150000.3.67.1      suse-cvrf  Security update for mozilla-nss  This update for mozilla-nss fixes the followin...     HIGH  [https://bugzilla.suse.com/1197903, https://li...  sha256:04fcd3db169b7fe1dfcb69d49bf7aae5ef1de03...     suse-cvrf       SUSE CVRF  https://ftp.suse.com/pub/projects/security/cvrf/     NaN        NaN    NaN           NaN              NaN               NaN               NaN               NaN               NaN                  NaN                  NaN  armdocker.rnd.ericsson.se/proj-mxe-ci-internal...  os-pkgs  suse linux enterprise server                  NaN                  NaN
# 2  keycloak-init@sha256:a616d074b14f04fd4a9aebd8b...  keycloak-init:2.3.0-dev-51           15.3  suse linux enterprise server  container_image  keycloak-init:2.3.0-dev-51  keycloak-init.json  SUSE-SU-2022:1158-1     liblzma5      5.2.3-4.3.1    5.2.3-150000.4.7.1      suse-cvrf           Security update for xz  This update for xz fixes the following issues:...     HIGH  [https://bugzilla.suse.com/1198062, https://li...  sha256:a5712801d34708e0dde3b47ff22db82bd2701dc...     suse-cvrf       SUSE CVRF  https://ftp.suse.com/pub/projects/security/cvrf/     NaN        NaN    NaN           NaN              NaN               NaN               NaN               NaN               NaN                  NaN                  NaN  armdocker.rnd.ericsson.se/proj-mxe-ci-internal...  os-pkgs  suse linux enterprise server                  NaN                  NaN
# 3  keycloak-init@sha256:a616d074b14f04fd4a9aebd8b...  keycloak-init:2.3.0-dev-51           15.3  suse linux enterprise server  container_image  keycloak-init:2.3.0-dev-51  keycloak-init.json  SUSE-SU-2022:1149-1  libsoftokn3    3.68.2-3.64.2  3.68.3-150000.3.67.1      suse-cvrf  Security update for mozilla-nss  This update for mozilla-nss fixes the followin...     HIGH  [https://bugzilla.suse.com/1197903, https://li...  sha256:04fcd3db169b7fe1dfcb69d49bf7aae5ef1de03...     suse-cvrf       SUSE CVRF  https://ftp.suse.com/pub/projects/security/cvrf/     NaN        NaN    NaN           NaN              NaN               NaN               NaN               NaN               NaN                  NaN                  NaN  armdocker.rnd.ericsson.se/proj-mxe-ci-internal...  os-pkgs  suse linux enterprise server                  NaN                  NaN
# 4  keycloak-init@sha256:a616d074b14f04fd4a9aebd8b...  keycloak-init:2.3.0-dev-51           15.3  suse linux enterprise server  container_image  keycloak-init:2.3.0-dev-51  keycloak-init.json  SUSE-SU-2022:1149-1  mozilla-nss    3.68.2-3.64.2  3.68.3-150000.3.67.1      suse-cvrf  Security update for mozilla-nss  This update for mozilla-nss fixes the followin...     HIGH  [https://bugzilla.suse.com/1197903, https://li...  sha256:04fcd3db169b7fe1dfcb69d49bf7aae5ef1de03...     suse-cvrf       SUSE CVRF  https://ftp.suse.com/pub/projects/security/cvrf/     NaN        NaN    NaN           NaN              NaN               NaN               NaN               NaN               NaN                  NaN                  NaN  armdocker.rnd.ericsson.se/proj-mxe-ci-internal...  os-pkgs  suse linux enterprise server                  NaN                  NaN

# %% [markdown]
# ### Count of modules by CVE

# %%
cve_with_modules_df = modified_base_df[['VulnerabilityID', 'Severity', 'repoTags']].copy().drop_duplicates()
cve_with_modules_df.columns=['cve_id', 'severity', 'image_name']
cve_with_modules_df['image_name']= cve_with_modules_df.groupby(['cve_id', 'severity'])['image_name'].transform(lambda x : '|'.join(x))
cve_with_modules_df['image_count']= cve_with_modules_df.apply(lambda rec: len(rec['image_name'].split('|')), axis=1)
cve_with_modules_df.drop_duplicates(inplace=True)
cve_with_modules_df['rank'] = cve_with_modules_df['severity'].map(SEVERITY_DICT)
cve_with_modules_df.sort_values(by=['rank','image_count'],ascending=[True, True],inplace=True)
cve_with_modules_df = cve_with_modules_df.drop(labels=['rank'],axis=1).reset_index(drop=True)

print(cve_with_modules_df)
# Out:
#                  cve_id  severity                                         image_name  image_count
# 0        CVE-2022-28391  CRITICAL                                   gui:2.3.0-dev-51            1
# 1        CVE-2022-26612  CRITICAL                     spark-operator:3.49.0-4-1.1.19            1
# 2        CVE-2022-21724  CRITICAL               eric-sec-access-mgmt-image:11.0.0-73            1
# 3        CVE-2021-43816  CRITICAL                            eric-pm-server:9.0.0-27            1
# 4        CVE-2022-22965  CRITICAL                             eric-ctrl-bro:5.4.0-35            1
# 5         CVE-2022-0839  CRITICAL  author-service:2.3.0-dev-51|model-catalogue-se...            4
# 6   SUSE-SU-2022:1164-1      HIGH                       pre-upgrade-job:2.3.0-dev-51            1
# 7        CVE-2022-23308      HIGH                                   gui:2.3.0-dev-51            1
# 8        CVE-2021-30560      HIGH                                   gui:2.3.0-dev-51            1
# 9         CVE-2022-1271      HIGH                                   gui:2.3.0-dev-51            1
# 10       CVE-2018-25032      HIGH                                   gui:2.3.0-dev-51            1
# 11       CVE-2019-10172      HIGH                            jupyterlab:2.3.0-dev-51            1
# 12       CVE-2022-24757      HIGH                            jupyterlab:2.3.0-dev-51            1
# 13       CVE-2022-24758      HIGH                            jupyterlab:2.3.0-dev-51            1
# 14       CVE-2022-25235      HIGH                            jupyterhub:2.3.0-dev-51            1
# 15       CVE-2022-25236      HIGH                            jupyterhub:2.3.0-dev-51            1
# 16       CVE-2022-24407      HIGH                            jupyterhub:2.3.0-dev-51            1
# 17        CVE-2022-0001      HIGH                            jupyterhub:2.3.0-dev-51            1
# 18        CVE-2022-0002      HIGH                            jupyterhub:2.3.0-dev-51            1
# 19        CVE-2022-0492      HIGH                            jupyterhub:2.3.0-dev-51            1
# 20        CVE-2022-1055      HIGH                            jupyterhub:2.3.0-dev-51            1
# 21       CVE-2022-23960      HIGH                            jupyterhub:2.3.0-dev-51            1
# 22       CVE-2022-25636      HIGH                            jupyterhub:2.3.0-dev-51            1
# 23       CVE-2021-41092      HIGH                      argocd:v2.3.3-ubuntu-20220415            1
# 24       CVE-2019-16884      HIGH                      argocd:v2.3.3-ubuntu-20220415            1
# 25       CVE-2019-19921      HIGH                      argocd:v2.3.3-ubuntu-20220415            1
# 26       CVE-2021-30465      HIGH                      argocd:v2.3.3-ubuntu-20220415            1
# 27        CVE-2020-9492      HIGH                     spark-operator:3.49.0-4-1.1.19            1
# 28       CVE-2021-25741      HIGH                     spark-operator:3.49.0-4-1.1.19            1
# 29       CVE-2021-22570      HIGH                    ambassador:1.14.2-alpine-3.15.4            1
# 30       CVE-2022-24765      HIGH                    argoexec:v3.2.9-ubuntu-20220415            1
# 31       CVE-2021-33503      HIGH    seldon-core-s2i-python37:1.12.0-ubuntu-20220415            1
# 32       CVE-2022-23913      HIGH               eric-sec-access-mgmt-image:11.0.0-73            1
# 33       CVE-2021-40690      HIGH               eric-sec-access-mgmt-image:11.0.0-73            1
# 34       CVE-2021-30129      HIGH               eric-sec-access-mgmt-image:11.0.0-73            1
# 35       CVE-2020-13949      HIGH               eric-sec-access-mgmt-image:11.0.0-73            1
# 36       CVE-2021-37714      HIGH               eric-sec-access-mgmt-image:11.0.0-73            1
# 37        CVE-2014-3530      HIGH               eric-sec-access-mgmt-image:11.0.0-73            1
# 38        CVE-2022-0778      HIGH           gui:2.3.0-dev-51|jupyterhub:2.3.0-dev-51            2
# 39       CVE-2022-24785      HIGH    jupyterlab:2.3.0-dev-51|jupyterhub:2.3.0-dev-51            2
# 40        CVE-2022-1015      HIGH  jupyterhub:2.3.0-dev-51|seldon-core-s2i-python...            2
# 41       CVE-2021-41103      HIGH  argocd:v2.3.3-ubuntu-20220415|eric-log-shipper...            2
# 42        CVE-2021-3121      HIGH  pre-upgrade-job:2.3.0-dev-51|spark-operator:3....            3
# 43       CVE-2022-23648      HIGH  argocd:v2.3.3-ubuntu-20220415|eric-pm-server:9...            3
# 44  SUSE-SU-2022:0713-1      HIGH  eric-sec-access-mgmt-authnproxy:11.0.0-73|eric...            4
# 45  SUSE-SU-2022:0743-1      HIGH  eric-sec-access-mgmt-authnproxy:11.0.0-73|eric...            4
# 46     CVE-2018-1000538      HIGH  model-packager:2.3.0-dev-51|model-python-base:...            5
# 47       CVE-2021-43858      HIGH  model-packager:2.3.0-dev-51|model-python-base:...            5
# 48       CVE-2020-26160      HIGH  model-packager:2.3.0-dev-51|model-python-base:...            6
# 49       CVE-2021-42836      HIGH  model-packager:2.3.0-dev-51|model-python-base:...            6
# 50        CVE-2018-1098      HIGH  model-packager:2.3.0-dev-51|model-python-base:...            6
# 51       CVE-2020-36518      HIGH  jupyterlab:2.3.0-dev-51|spark-operator:3.49.0-...            7
# 52  SUSE-SU-2022:1149-1      HIGH  keycloak-init:2.3.0-dev-51|model-service:2.3.0...           14
# 53       CVE-2022-27191      HIGH  pre-upgrade-job:2.3.0-dev-51|eric-mxe-gatekeep...           19
# 54  SUSE-SU-2022:0844-1      HIGH  keycloak-init:2.3.0-dev-51|db-init:2.3.0-dev-5...           22
# 55  SUSE-SU-2022:1158-1      HIGH  keycloak-init:2.3.0-dev-51|db-init:2.3.0-dev-5...           41

# %%
cve_with_modules_df.to_html(f"{output_dir}/{REPORT_NAMES['IMAGE_COUNT_BY_CVE']}.html")
cve_with_modules_df.to_csv(f"{output_dir}/{REPORT_NAMES['IMAGE_COUNT_BY_CVE']}.csv", index=False)

# %% [markdown]
# ## CVEs by Month Year
#
# Reused code written for Anchore.
#
# If LastModifiedDate is Nan, fill with 1900-01-01

# %%
cve_by_date_severity_df = modified_base_df[['Severity', 'VulnerabilityID', 'LastModifiedDate']].copy()

cve_by_date_severity_df['LastModifiedDate'].fillna(value='1900-01-01T00:00Z', inplace=True)

cve_by_date_severity_df['LastModifiedDateTime']=pd.to_datetime(cve_by_date_severity_df['LastModifiedDate'])
cve_by_date_severity_df['MonthYear'] = pd.DatetimeIndex(cve_by_date_severity_df['LastModifiedDate']).strftime('%Y-%m')

severity_by_month_year_interim_df = cve_by_date_severity_df.sort_values(by=['LastModifiedDateTime'], ascending=False).drop(['LastModifiedDateTime'], axis=1)

severity_by_month_year_df = severity_by_month_year_interim_df[['MonthYear','VulnerabilityID', 'Severity']].drop_duplicates()

severity_by_month_year_df = severity_by_month_year_df.drop("VulnerabilityID", axis=1).value_counts().reset_index()

severity_by_month_year_df.columns = ['MonthYear', 'Severity', 'CVE_Count']

severity_by_month_year_df
# Out:
#    MonthYear  Severity  CVE_Count
# 0    2022-04      HIGH         23
# 1    1900-01      HIGH          8
# 2    2022-03      HIGH          5
# 3    2022-04  CRITICAL          5
# 4    2021-11      HIGH          4
# 5    2021-07      HIGH          2
# 6    2018-01      HIGH          1
# 7    2018-08      HIGH          1
# 8    2019-05      HIGH          1
# 9    2020-03      HIGH          1
# 10   2021-08      HIGH          1
# 11   2021-10      HIGH          1
# 12   2021-12      HIGH          1
# 13   2022-01      HIGH          1
# 14   2022-03  CRITICAL          1

# %% [markdown]
# ## Pivot report - Not sorted

# %%
pivot_df = severity_by_month_year_df.pivot_table(index='MonthYear', columns='Severity', values='CVE_Count', fill_value=0)

pivot_df
# Out:
# Severity   CRITICAL  HIGH
# MonthYear
# 1900-01           0     8
# 2018-01           0     1
# 2018-08           0     1
# 2019-05           0     1
# 2020-03           0     1
# 2021-07           0     2
# 2021-08           0     1
# 2021-10           0     1
# 2021-11           0     4
# 2021-12           0     1
# 2022-01           0     1
# 2022-03           1     5
# 2022-04           5    23

# %% [markdown]
# ## Pivot Report - Sorted by MonthYear

# %%
format_pivot_df = pivot_df.reset_index()

format_pivot_df['MonthDate'] = pd.to_datetime(format_pivot_df['MonthYear'])

format_pivot_df.sort_values(by='MonthDate', ascending=False, inplace=True)

format_pivot_df.set_index(['MonthYear'], inplace=True)

format_pivot_df.drop(['MonthDate'], inplace=True, axis=1)

format_pivot_df
# Out:
# Severity   CRITICAL  HIGH
# MonthYear
# 2022-04           5    23
# 2022-03           1     5
# 2022-01           0     1
# 2021-12           0     1
# 2021-11           0     4
# 2021-10           0     1
# 2021-08           0     1
# 2021-07           0     2
# 2020-03           0     1
# 2019-05           0     1
# 2018-08           0     1
# 2018-01           0     1
# 1900-01           0     8

# %%
format_pivot_df.to_html(f"{output_dir}/{REPORT_NAMES['CVE_COUNT_BY_SEVERITY_AND_AGE']}.html")
format_pivot_df.to_csv(f"{output_dir}/{REPORT_NAMES['CVE_COUNT_BY_SEVERITY_AND_AGE']}.csv", index=False)

# %%
with pd.ExcelWriter(f"{output_dir}/trivy_{REPORT_NAMES['CONSOLIDATED_EXCEL_REPORT']}.xlsx") as excelWriter: 
    detailed_report_df.to_excel(excelWriter, sheet_name=REPORT_NAMES['DETAILED_REPORT'], index=False)
    severity_counts_df.to_excel(excelWriter, sheet_name=REPORT_NAMES['CVE_COUNT_BY_SEVERITY'], index=False)
    cve_with_modules_df.to_excel(excelWriter, sheet_name=REPORT_NAMES['IMAGE_COUNT_BY_CVE'], index=False)
    format_pivot_df.to_excel(excelWriter, sheet_name=REPORT_NAMES['CVE_COUNT_BY_SEVERITY_AND_AGE'], index=True)
